# %%
#import most used libraries for machine learning and deep learning
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#read csv as a pandas dataframe
df_train = pd.read_csv('mitbih_train.csv')
df_test = pd.read_csv('mitbih_test.csv')

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (87553, 188)
# (21891, 188)

# %%
#separate last column as target
data_matrix = df_train.values
y = data_matrix[:,-1]
X = data_matrix[:,0:-1]

#plot some examples of the data
plt.figure(figsize=(12, 6))
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.plot(X[i-1])
    plt.title(f'Label: {round((y[i-1]))}')
    plt.tight_layout()
plt.show()

# %%
# Create a histogram of the vector y
plt.figure(figsize=(12, 6))
plt.hist(y, bins='auto', color='blue', edgecolor='black')
plt.title('Histogram of y')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# ResCNN_mitbih model trained on mitbih dataset
# Used: dataset_q1.py, train_test.py, model_q1.py
